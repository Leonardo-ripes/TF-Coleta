# %%
# importando bibliotecas
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dados/Censo/populacao_raca_2019.csv')
df
# Out:
#     uf  total_pessoas  perc_branca  perc_preta  perc_parda  \
# 0   RO           1767         28.3         7.1        63.5
# 1   AC            865         18.3         6.0        74.2
# 2   AM           3983         15.5         3.3        78.8
# 3   RR            540         19.8         8.5        65.1
# 4   PA           8561         18.4         8.3        72.3
# 5   AP            838         18.3         7.6        73.6
# 6   TO           1560         19.9        12.3        66.2
# 7   MA           7041         17.7        12.8        68.6
# 8   PI           3272         18.8        10.4        70.6
# 9   CE           9129         26.9         5.9        66.5
# 10  RN           3507         38.3         8.1        53.3
# 11  PB           3997         32.1         7.0        60.4
# 12  PE           9499         31.0         7.2        60.6
# 13  AL           3330         25.0         5.6        68.3
# 14  SE           2299         20.0         9.9        69.2
# ...
